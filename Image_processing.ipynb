# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: C:\Users\dsavr\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt 
from PIL import Image, ImageOps

# %%
img_png = np.array(Image.open('Tiger_Saved.png'))
plt.imshow(img_png)

# %%
img.ndim
# Out:
# 3

# %%
img.shape
# Out:
# (630, 1400, 3)

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
img[400,400]
# Out:
# array([14,  3,  9], dtype=uint8)

# %%
path = 'Tiger_1.jpeg'
pil_image = Image.fromarray(img)
pil_image.save(path)

# %%
img = np.array(Image.open('Tiger_1.jpeg'))
plt.imshow(img)

# %%
img.shape
# Out:
# (630, 1400, 3)

# %%
arr = np.array(img)         # converting into array

# %%
img.ndim
# Out:
# 3

# %%
img[400,400]
# Out:
# array([18,  8,  7], dtype=uint8)

# %%
flat_arr = arr.ravel()              # matrix to 1d array
flat_arr
# Out:
# array([ 39,  62,  42, ...,  46, 140,  28], dtype=uint8)

# %%
vector = np.matrix(flat_arr)            # converting flattened array to matrix
vector
# Out:
# matrix([[ 39,  62,  42, ...,  46, 140,  28]], dtype=uint8)

# %%
vector[:,::10] = 128

# %%
vector[:,::10] = 128 # changing the pixels at a particular location

# %%
arr2 = np.asarray(vector).reshape(arr.shape) 
# first converting matrix to array and also reshaping it

# %%
img2 = Image.fromarray(arr2,'RGB')   # Conversion of numpy to image
img2.show()

# %%
plt.imshow(img2)

# %%
img_png = np.array(Image.open('Tiger_Saved.png'))
plt.imshow(img_png)

# %%
img_flat = img_png.flatten()    # if we want to see the density of pixels

# %%
plt.hist(img_flat,bins = 200,range=[0,256])  # if we want to see the density of pixels-
plt.title("No of Pixels with intensity")
plt.xlabel('Intensity')
plt.ylabel('No of pixels')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 img_png.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'show'

# %%
plt.imshow(np.flipud(img_png))

# %%
plt.imshow(np.rot90(img_png))

# %%
plt.imshow(np.fliplr(img_png))

# %%
img0 = img_png[128:-128,128:-128,:]   # image cropping
plt.imshow(img0)

# %%
img0 = img_png[128:-128,128:-128,:1]            # gray scale image
plt.imshow(img0)

# %%
img_grey = img_png.sum(2)/(255*3)
plt.imshow(img_grey)

# %%
img_grey = (255*3) - img_grey
plt.imshow(img_grey)
